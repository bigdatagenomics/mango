# %%
################ For testing purposes only ################
try:
   testMode
except NameError:
   testMode = False

try:
    coverageFile
except NameError:
   # NOTE: this is for a local example. Based on file placement, you may have to change this path
    coverageFile = os.getcwd() + "/chr17.7500000-7515000.sam.coverage.adam"

# %%
import os 

from bdgenomics.adam.adamContext import ADAMContext
from bdgenomics.adam.rdd import AlignmentRecordRDD, CoverageRDD

from bdgenomics.mango.QC import CoverageDistribution, AlignmentDistribution

# %%
ac = ADAMContext(sc)

# load file
coverage = ac.loadCoverage(coverageFile)

# %%
cd = CoverageDistribution(sc, coverage)

# %%
results = cd.plot(cumulative=False, testMode=testMode)

# %%
################ For testing purposes only ################
try:
   testMode
except NameError:
   testMode = False

try:
    alignmentFile
except NameError:
   # NOTE: this is for a local example. Based on file placement, you may have to change this path
    alignmentFile = os.getcwd() + "/chr17.7500000-7515000.sam.adam"

# %%
# load file
alignment = ac.loadAlignments(alignmentFile)

# %%
ad = AlignmentDistribution(sc, [alignment, alignment], bin_size=500)

# %%
results = ad.plot(plot_type="M")
